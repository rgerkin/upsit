# %%
# Preliminaries
from IPython.core.display import HTML
from scratch import get_fig,get_table,display
def Fig(name,cell):
    return get_fig('upsit_%s' % name,cell) 
def Table(name,cell):
    return get_table('upsit_%s' % name,cell) 
HTML("""<style>hr {height: 2px; background-color: #333;}</style>""")
# Out:
# Using Theano backend.
# <style>hr {height: 2px; background-color: #333;}</style>

# %% [markdown]
# <hr>
# ## Figure 1a

# %%
Fig('mnb',3)

# %% [markdown]
# #### a) For non-demented subjects with no comorbidities, the cumulative probability of a given UPSIT score for those with a pathological diagnosis of PD (red) vs no such diagnosis (black).

# %% [markdown]
# <hr>
# ## Figure 1b

# %%
Fig('mnb',6)

# %% [markdown]
# #### b) For the subjects in (a), the receiver-operating-characteristic (ROC) curve using the total score on the UPSIT (black) vs using the individual responses to each of the 40 UPSIT test questions (green).  Using the individual responses reduces the region of predictive failure by more than half.

# %% [markdown]
# <hr>
# ## Figure 1c

# %%
Fig('mnb',8)

# %% [markdown]
# #### c) Similar to (a), but includes pathological comorbidities and clinical dementia.

# %% [markdown]
# <hr>
# ## Figure 1d

# %%
Fig('mnb',11)

# %% [markdown]
# #### d) Similar to (b), but includes pathological comorbidities and clinical dementia.

# %% [markdown]
# <hr>
# ## Figure 2

# %%
Fig('multiclass_joe',10)

# %% [markdown]
# #### 2) Probability distributions for the statistical model's predicted probability of a given diagnostic label, separated post hoc into subjects that did not--by pathological assessment--have that label (yellow), and those that did (blue).  All predicted probabilities are computed on hold-out data that was not used to fit the model.  Only for PD and related pathologies were the positive cases (blue) predicted at a substantially higher rate than the negative cases (yellow).

# %% [markdown]
# <hr>
# ## Figure 3

# %%
Fig('multiclass_joe',12)

# %% [markdown]
# #### 3) For the data from Figure 2, ROC analysis shows that PD and related pathologies are more accurately predicted when all the UPSIT test questions are used (red) than when only the total score is used (pink) or when only basic subject information (gender, age, dementia status) is used (gray).

# %% [markdown]
# <hr>
# ## Figure 4

# %%
Fig('all_data',10)

# %% [markdown]
# #### 4) Using a large body of clinical information available through the BBDP, including clinical analysis of potential dyskinesias, it is possible to predict a wide variety of post-mortem pathological diagnoses with almost perfect accuracy on a hold-out dataset, using only pre-mortem clinical measures.

# %% [markdown]
# <hr>
# ## Table 1

# %%
Table('all_data',12)
# Out:
# <span style="font-size:50%; line-height:140%"><html><body><table border="1" class="dataframe">
# <thead>
# <tr style="text-align: right;">
# <th width="50px"></th>
# <th width="50px">MCI</th>
# <th width="50px">Control</th>
# <th width="50px">Lewy Bodies NOS</th>
# <th width="50px">Dementia NOS</th>
# <th width="50px">AD</th>
# <th width="50px">PD</th>
# <th width="50px">DLB</th>
# <th width="50px">VaD</th>
# <th width="50px">PSP</th>
# <th width="50px">HS</th>
# <th width="50px">DLDH</th>
# <th width="50px">MND</th>
# <th width="50px">CBD</th>
# <th width="50px">ARG</th>
# <th width="50px">FTLD-TDP43</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th width="50px">1</th>
# <td style="font-size:9px;">last bmi score</td>
# <td style="font-size:10px;">last mmse test score</td>
# <td style="font-size:9px;">last mmse test score</td>
# <td style="font-size:9px;">dementia</td>
# <td style="font-size:11px;">last mmse test score</td>
# <td style="font-size:10px;">hours since last pd </td>
# ...

# %% [markdown]
# #### T1) The statistical model uses dozens of features (out of over hundred available) to predict post-mortem pathologies, and for each diagnosis (column headers), the top 10 such features are indicated.  Features that were especially important are indicated with increased font size.  Smell-related features are indicated in red.  These smell-related features (largely UPSIT individual question responses) make up a large fraction of the top 10 most diagnostic features for many of the pathologies.

# %% [markdown]
# <hr>
# ## Figure 5

# %%
Fig('all_data',14)

# %% [markdown]
# #### 5) Same as Figure 4, but excluding all smell-related information including UPSIT scores and question responses.  Predictive power is still higher, but noticeably lower than for the model that included this information.

# %% [markdown]
# <hr>
# ## Figure 6

# %%
Fig('all_data',16)

# %% [markdown]
# #### 6) Same as Figure 4, but excluding information about subjective clinical PD assessment or dyskinesia metrics.  Even without this information, the model performs with extremely high accuracy, in fact outpeforming the original model in many cases.

# %% [markdown]
# <hr>
# ## Table 2

# %%
Table('all_data',17)
# Out:
# <span style="font-size:60%; line-height:140%"><html><body><table border="1" class="dataframe">
# <thead>
# <tr style="text-align: right;">
# <th width="50px"></th>
# <th width="50px">MCI</th>
# <th width="50px">Control</th>
# <th width="50px">Lewy Bodies NOS</th>
# <th width="50px">Dementia NOS</th>
# <th width="50px">AD</th>
# <th width="50px">PD</th>
# <th width="50px">DLB</th>
# <th width="50px">VaD</th>
# <th width="50px">PSP</th>
# <th width="50px">HS</th>
# <th width="50px">DLDH</th>
# <th width="50px">MND</th>
# <th width="50px">CBD</th>
# <th width="50px">ARG</th>
# <th width="50px">FTLD-TDP43</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th width="50px">1</th>
# <td style="font-size:9px;">last mmse test score</td>
# <td style="font-size:11px;">last mmse test score</td>
# <td style="font-size:9px;">last mmse test score</td>
# <td style="font-size:10px;">dementia</td>
# <td style="font-size:12px;">last mmse test score</td>
# <td style="font-size:10px;">modified hoehn and y</td>
# ...

# %% [markdown]
# #### T1) Same as Table 1, but for the model without information about subjective clinical PD assessment or dyskinesia metrics.   Smell-related features make up an even larger fraction of the top 10 most diagnostic features than before.
